# %%
# !pip install pydes
import pyDes
data=input("enter plain text for encryption") 
key=input("enter 16/24 byte string for key generation")  
k=pyDes.triple_des(key, padmode=pyDes.PAD_PKCS5) 
e=k.encrypt(data)

print("cipher text:%r"%e) 
print("plain text:%r"%k.decrypt(e))
# Out:
# Collecting pydes
#   Downloading pyDes-2.0.1.tar.gz (9.9 kB)
# Building wheels for collected packages: pydes
#   Building wheel for pydes (setup.py) ... done
#   Created wheel for pydes: filename=pyDes-2.0.1-py2.py3-none-any.whl size=9566 sha256=75c2a55592035ab28a3c5f489abc98282bfede4e410160f32c693b54b7a152cd
#   Stored in directory: /root/.cache/pip/wheels/57/45/3a/cd3cffc8044aa6b8670109a57db784cc7c64dc52259a11575a
# Successfully built pydes
# Installing collected packages: pydes
# Successfully installed pydes-2.0.1
# enter plain text for encryptionhowareyouiaminpune
# enter 16/24 byte string for key generationhowareyouiamfine
# cipher text:b'*\x13W(\xe2\x83i!Z\x88E#\xbc\xb1\xcdp8\x9f\xe3C\x1a!\x01\xc4'
# plain text:b'howareyouiaminpune'
